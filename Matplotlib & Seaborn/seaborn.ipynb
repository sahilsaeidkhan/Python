# %%
import seaborn as sns

# %%
import pandas as pd

data = pd.DataFrame({
    "age":[20,22,25,30,35],
    "salary":[20000,25000,30000,40000,50000]
})

# %%
sns.scatterplot(x="age",y="salary",data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 sns.scatterplot(x="age",y="salary",data=data)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(x="age",y="salary",data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 sns.barplot(x="age",y="salary",data=data)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(data["salary"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 sns.histplot(data["salary"])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
corr = data.corr()

sns.heatmap(corr,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 corr = data.corr()
#       3 sns.heatmap(corr,annot=True)
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined
